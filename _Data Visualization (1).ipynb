# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.DataFrame({'Names':['Tharun','Kumar','Naveen'],'Science':[98,89,56],'Social':[89,43,75],'Maths':[34,78,89]})
df
df.set_index('Names', inplace=True)
df
# Out:
#         Science  Social  Maths
# Names
# Tharun       98      89     34
# Kumar        89      43     78
# Naveen       56      75     89

# %%
 
df[['Science','Social','Maths']].plot(kind='bar')
# Out:
# <Axes: xlabel='Names'>

# %%
df[['Science']].plot(kind='bar')
# Out:
# <Axes: xlabel='Names'>

# %%
#Line Plot
df[['Science','Social']].plot()
# Out:
# <Axes: xlabel='Names'>

# %%
#Scatter plot
df[['Science','Social']]
plt.scatter(df['Science'],df['Social'])

# %%
#Horizontal Bar plot
plt.barh(df['Science'],df['Social'])
# Out:
# <BarContainer object of 3 artists>

# %%
import numpy as np
data=np.random.randn(1000)
plt.hist(data)
# Out:
# (array([  4.,  23.,  89., 213., 250., 229., 128.,  47.,  12.,   5.]),
#  array([-3.24783692, -2.56708296, -1.886329  , -1.20557504, -0.52482109,
#          0.15593287,  0.83668683,  1.51744079,  2.19819475,  2.87894871,
#          3.55970267]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df['Science'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a6eba31810>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a6eba31a90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a6eba316d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a6eba31d10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a6eba31e50>],
#  'means': []}

# %%
 
plt.pie(df['Social'],labels=df.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x1a6ebe06350>,
# ...
#  [Text(0.24012039261137144, 1.0734720290031599, 'Tharun'),
#   Text(-1.0752631450965142, -0.23196803399855082, 'Kumar'),
#   Text(0.461094574254626, -0.9986950453431445, 'Naveen')])

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.DataFrame({'Names':['Tharun','Kumar','Naveen'],'Science':[98,89,56],'Social':[89,43,75],'Maths':[34,78,89]})
df
df.set_index('Names',inplace=True)
df[['Science','Social']].plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Names'>
